# %% [markdown]
# # Futures Contract Excercise

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 100;         
benefit         = 0;        
miscCharges     = 1;
t               = 25;      
r               = 0.05;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:100.00
# Expected benefits like dividend:0.00
# Expected costs to be incurred:1.00
# Time to expiry of the futures contract in days:25
# Interest Rate in percent:5.00
# Price of the futures contract:342.02

# %% [markdown]
# ## Lab Q1)
#
# Scenarios
#
# 1. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 1%
# 2. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 5%
# 3. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 8%
# 4. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 4%
# 5. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 10%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,2:8yrs,3:7yrs,4:6yrs,5:5yrs
#
# c) Same process as b) but with changed dividends. 1:50,2:40,3:30,4:20,5:5
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %% [markdown]
# # Scenario 1
#
# 1. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 1%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. (1:9yrs),2:8yrs,3:7yrs,4:6yrs,5:5yrs
#
# c) Same process as b) but with changed dividends. (1:50),2:40,3:30,4:20,5:5
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %%
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         = 10;
dividend_50     = 50;
miscCharges     = 20;
t               = 10;    
t_9             = 9;
r               = 0.01;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract: %3.2f"%spotPrice);
print("Expected benefits like dividend: %3.2f"%benefit);
print("Expected costs to be incurred: %3.2f"%miscCharges);
print("Time to expiry of the futures contract in days: %d"%t);
print("Interest Rate in percent: %2.2f"%(r*100));
print("Price of the futures Contract (with 1 percent risk free rate): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t_9);
print("Price of the futures Contratc (with time = 9 years): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, dividend_50, miscCharges, r, t);
print("Price of the futures Contract (with dividend = 50): %3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract: 150.00
# Expected benefits like dividend: 10.00
# Expected costs to be incurred: 20.00
# Time to expiry of the futures contract in days: 10
# Interest Rate in percent: 1.00
# Price of the futures Price (with 1 percent risk free rate): 176.74
# Price of the futures Price (with time = 9 years): 174.99
# Price of the futures Price (with dividend = 50): 132.55

# %% [markdown]
# # Scenario 2
#
# 2. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 5%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,(2:8yrs),3:7yrs,4:6yrs,5:5yrs
#
# c) Same process as b) but with changed dividends. 1:50,(2:40),3:30,4:20,5:5
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %%
#Scenario 2
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         = 10;        
miscCharges     = 20;
dividend_40     = 40;
t               = 10;
t_8             = 8;
r               = 0.05;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract: %3.2f"%spotPrice);
print("Expected benefits like dividend: %3.2f"%benefit);
print("Expected costs to be incurred: %3.2f"%miscCharges);
print("Time to expiry of the futures contract in days: %d"%t);
print("Risk free Rate in percent: %2.2f"%(r*100));
print("Price of the futures contract (with 5 percent risk free rate): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t_8);
print("Price of the futures contract (with time = 8 years): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, dividend_40, miscCharges, r, t);
print("Price of the futures contract (with dividend = 40): %3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract: 150.00
# Expected benefits like dividend: 10.00
# Expected costs to be incurred: 20.00
# Time to expiry of the futures contract in days: 10
# Risk free Rate in percent: 5.00
# Price of the futures contract (with 5 percent risk free rate): 260.62
# Price of the futures contract (with time = 8 years): 236.39
# Price of the futures contract (with dividend = 40): 211.76

# %% [markdown]
# # Scenario 3
# 3. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 8%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,2:8yrs,(3:7yrs),4:6yrs,5:5yrs
#
# c) Same process as b) but with changed dividends. 1:50,2:40,(3:30),4:20,5:5
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %%
#Scenario 3
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         = 10; 
dividend_30     = 30;
miscCharges     = 20;
t               = 10;  
t_7             = 7;
r               = 0.08;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract: %3.2f"%spotPrice);
print("Expected benefits like dividend: %3.2f"%benefit);
print("Expected costs to be incurred: %3.2f"%miscCharges);
print("Time to expiry of the futures contract in days: %d"%t);
print("Risk free Rate in percent: %2.2f"%(r*100));
print("Price of the futures Price (with 8 percent risk free rate): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t_7);
print("Price of the futures Price (with time = 7 years): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, dividend_30, miscCharges, r, t);
print("Price of the futures Price (with dividend = 30): %3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract: 150.00
# Expected benefits like dividend: 10.00
# Expected costs to be incurred: 20.00
# Time to expiry of the futures contract in days: 10
# Risk free Rate in percent: 8.00
# Price of the futures Price (with 8 percent risk free rate): 345.43
# Price of the futures Price (with time = 7 years): 274.21
# Price of the futures Price (with dividend = 30): 302.25

# %% [markdown]
# # Scenario 4
# 4. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 4%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,2:8yrs,3:7yrs,(4:6yrs),5:5yrs
#
# c) Same process as b) but with changed dividends. 1:50,2:40,3:30,(4:20),5:5
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %%
#Scenario 1
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         = 10; 
dividend_20     = 20;
miscCharges     = 20;
t               = 10;
t_6             = 6;
r               = 0.04;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract: %3.2f"%spotPrice);
print("Expected benefits like dividend: %3.2f"%benefit);
print("Expected costs to be incurred: %3.2f"%miscCharges);
print("Time to expiry of the futures contract in days: %d"%t);
print("Risk free Rate in percent: %2.2f"%(r*100));
print("Price of the futures Price (with 4 percent risk free rate): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t_6);
print("Price of the futures Price (with time = 6 years): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, dividend_20, miscCharges, r, t);
print("Price of the futures Price (with dividend = 20): %3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract: 150.00
# Expected benefits like dividend: 10.00
# Expected costs to be incurred: 20.00
# Time to expiry of the futures contract in days: 10
# Risk free Rate in percent: 4.00
# Price of the futures Price (with 4 percent risk free rate): 236.84
# Price of the futures Price (with time = 6 years): 202.45
# Price of the futures Price (with dividend = 20): 222.04

# %% [markdown]
# # Scenario 5
# 5. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 10%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,2:8yrs,3:7yrs,4:6yrs,(5:5yrs)
#
# c) Same process as b) but with changed dividends. 1:50,2:40,3:30,4:20,(5:5)
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %%
#Scenario 1
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         = 10;   
dividend_5      = 5;
miscCharges     = 20;
t               = 10;   
t_5             = 5;
r               = 0.1;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract: %3.2f"%spotPrice);
print("Expected benefits like dividend: %3.2f"%benefit);
print("Expected costs to be incurred: %3.2f"%miscCharges);
print("Time to expiry of the futures contract in days: %d"%t);
print("Risk free Rate in percent: %2.2f"%(r*100));
print("Price of the futures Price (with 10 percent risk free rate): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t_5);
print("Price of the futures Price (with time = 5 years): %3.2f"%contractPrice)

contractPrice   = FuturePrice(spotPrice, dividend_5, miscCharges, r, t);
print("Price of the futures Price (with dividend = 5): %3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract: 150.00
# Expected benefits like dividend: 10.00
# Expected costs to be incurred: 20.00
# Time to expiry of the futures contract in days: 10
# Risk free Rate in percent: 10.00
# Price of the futures Price (with 10 percent risk free rate): 415.00
# Price of the futures Price (with time = 5 years): 257.68
# Price of the futures Price (with dividend = 5): 427.97

# %% [markdown]
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).
#
#
#
# ![answerpartd.png](answerpartd.png)
